# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import warnings
warnings.simplefilter(action='ignore')

import preprocessing, utils

# %%
emb_name_dims = ['50D', '100D', '200D', '300D']
model_names = ['LSTM', 'bidirectional LSTM']

epochs = 5
batch_size = 64

# %%
try:
    X_train, y_train, X_test, y_test, tokenizer = preprocessing.read_preprocessed_comments()
except FileNotFoundError:
    X_train, y_train, X_test, y_test, tokenizer = preprocessing.preprocess_comments()

# %%
for emb_name_dim in emb_name_dims:
    emb_name = f'GloVe 6B {emb_name_dim}'
    emb_dim = int(emb_name.split()[-1].replace('D', ''))
    emb_matrix = utils.create_embedding_matrix(tokenizer, emb_name, emb_dim)
    
    for model_name in model_names:
        print(f'============ {emb_name} - {model_name} ============\n')
        model = utils.define_model(model_name, emb_matrix, emb_dim)
        model = utils.train_model(model, X_train, y_train, epochs, batch_size)
        utils.calculate_score(model, X_test, y_test, model_name, emb_name)
# Out:
# ============ GloVe 6B 50D - LSTM ============
#
# Epoch 1/5
# 2244/2244 [==============================] - 399s 177ms/step - loss: 0.0771 - auc: 0.9521 - val_loss: 0.0581 - val_auc: 0.9756
# Epoch 2/5
# 2244/2244 [==============================] - 373s 166ms/step - loss: 0.0561 - auc: 0.9742 - val_loss: 0.0542 - val_auc: 0.9777
# Epoch 3/5
# 2244/2244 [==============================] - 397s 177ms/step - loss: 0.0523 - auc: 0.9788 - val_loss: 0.0521 - val_auc: 0.9802
# Epoch 4/5
# 2244/2244 [==============================] - 420s 187ms/step - loss: 0.0495 - auc: 0.9805 - val_loss: 0.0523 - val_auc: 0.9764
# Epoch 4: early stopping
# 63/63 [==============================] - 34s 532ms/step
#
# The mean column-wise ROC AUC score for LSTM with GloVe 6B 50D is 0.972
#
#
#
# ============ GloVe 6B 50D - bidirectional LSTM ============
#
# Epoch 1/5
# 2244/2244 [==============================] - 946s 420ms/step - loss: 0.0725 - auc_1: 0.9571 - val_loss: 0.0589 - val_auc_1: 0.9744
# Epoch 2/5
# 2244/2244 [==============================] - 891s 397ms/step - loss: 0.0565 - auc_1: 0.9750 - val_loss: 0.0555 - val_auc_1: 0.9768
# Epoch 3/5
# 2244/2244 [==============================] - 891s 397ms/step - loss: 0.0522 - auc_1: 0.9790 - val_loss: 0.0533 - val_auc_1: 0.9802
# Epoch 4/5
# 2244/2244 [==============================] - 892s 398ms/step - loss: 0.0495 - auc_1: 0.9810 - val_loss: 0.0525 - val_auc_1: 0.9754
# Epoch 5/5
# 2244/2244 [==============================] - 910s 406ms/step - loss: 0.0475 - auc_1: 0.9822 - val_loss: 0.0507 - val_auc_1: 0.9790
# 63/63 [==============================] - 48s 758ms/step
#
# The mean column-wise ROC AUC score for bidirectional LSTM with GloVe 6B 50D is 0.97388
#
#
#
# ============ GloVe 6B 100D - LSTM ============
#
# Epoch 1/5
# 2244/2244 [==============================] - 432s 192ms/step - loss: 0.0698 - auc_2: 0.9614 - val_loss: 0.0549 - val_auc_2: 0.9784
# Epoch 2/5
# 2244/2244 [==============================] - 428s 191ms/step - loss: 0.0526 - auc_2: 0.9784 - val_loss: 0.0507 - val_auc_2: 0.9792
# Epoch 3/5
# 2244/2244 [==============================] - 440s 196ms/step - loss: 0.0486 - auc_2: 0.9818 - val_loss: 0.0499 - val_auc_2: 0.9791
# Epoch 4/5
# 2244/2244 [==============================] - 467s 208ms/step - loss: 0.0461 - auc_2: 0.9840 - val_loss: 0.0489 - val_auc_2: 0.9795
# Epoch 5/5
# 2244/2244 [==============================] - 420s 187ms/step - loss: 0.0440 - auc_2: 0.9851 - val_loss: 0.0479 - val_auc_2: 0.9804
# 63/63 [==============================] - 37s 580ms/step
#
# The mean column-wise ROC AUC score for LSTM with GloVe 6B 100D is 0.97508
#
#
#
# ============ GloVe 6B 100D - bidirectional LSTM ============
#
# Epoch 1/5
# 2244/2244 [==============================] - 948s 421ms/step - loss: 0.0661 - auc_3: 0.9647 - val_loss: 0.0557 - val_auc_3: 0.9799
# Epoch 2/5
# 2244/2244 [==============================] - 945s 421ms/step - loss: 0.0511 - auc_3: 0.9794 - val_loss: 0.0502 - val_auc_3: 0.9808
# Epoch 3/5
# 2244/2244 [==============================] - 944s 421ms/step - loss: 0.0470 - auc_3: 0.9833 - val_loss: 0.0482 - val_auc_3: 0.9804
# Epoch 4/5
# 2244/2244 [==============================] - 943s 420ms/step - loss: 0.0441 - auc_3: 0.9856 - val_loss: 0.0482 - val_auc_3: 0.9819
# Epoch 5/5
# 2244/2244 [==============================] - 947s 422ms/step - loss: 0.0422 - auc_3: 0.9865 - val_loss: 0.0481 - val_auc_3: 0.9827
# 63/63 [==============================] - 56s 890ms/step
#
# The mean column-wise ROC AUC score for bidirectional LSTM with GloVe 6B 100D is 0.97804
#
#
#
# ============ GloVe 6B 200D - LSTM ============
#
# Epoch 1/5
# 2244/2244 [==============================] - 470s 209ms/step - loss: 0.0674 - auc_4: 0.9639 - val_loss: 0.0525 - val_auc_4: 0.9779
# Epoch 2/5
# 2244/2244 [==============================] - 467s 208ms/step - loss: 0.0503 - auc_4: 0.9800 - val_loss: 0.0497 - val_auc_4: 0.9813
# Epoch 3/5
# 2244/2244 [==============================] - 473s 211ms/step - loss: 0.0461 - auc_4: 0.9841 - val_loss: 0.0487 - val_auc_4: 0.9830
# Epoch 4/5
# 2244/2244 [==============================] - 484s 216ms/step - loss: 0.0428 - auc_4: 0.9865 - val_loss: 0.0509 - val_auc_4: 0.9725
# Epoch 4: early stopping
# 63/63 [==============================] - 48s 751ms/step
#
# The mean column-wise ROC AUC score for LSTM with GloVe 6B 200D is 0.97632
#
#
#
# ============ GloVe 6B 200D - bidirectional LSTM ============
#
# Epoch 1/5
# 2244/2244 [==============================] - 1150s 511ms/step - loss: 0.0674 - auc_5: 0.9630 - val_loss: 0.0530 - val_auc_5: 0.9789
# Epoch 2/5
# 2244/2244 [==============================] - 1333s 594ms/step - loss: 0.0498 - auc_5: 0.9810 - val_loss: 0.0516 - val_auc_5: 0.9813
# Epoch 3/5
# 2244/2244 [==============================] - 1140s 508ms/step - loss: 0.0455 - auc_5: 0.9842 - val_loss: 0.0483 - val_auc_5: 0.9830
# Epoch 4/5
# 2244/2244 [==============================] - 1142s 509ms/step - loss: 0.0427 - auc_5: 0.9864 - val_loss: 0.0478 - val_auc_5: 0.9822
# Epoch 5/5
# 2244/2244 [==============================] - 1145s 510ms/step - loss: 0.0401 - auc_5: 0.9883 - val_loss: 0.0482 - val_auc_5: 0.9828
# Epoch 5: early stopping
# 63/63 [==============================] - 78s 1s/step
#
# The mean column-wise ROC AUC score for bidirectional LSTM with GloVe 6B 200D is 0.9783
#
#
#
# ============ GloVe 6B 300D - LSTM ============
#
# Epoch 1/5
# 2244/2244 [==============================] - 487s 216ms/step - loss: 0.0669 - auc_6: 0.9657 - val_loss: 0.0524 - val_auc_6: 0.9799
# Epoch 2/5
# 2244/2244 [==============================] - 485s 216ms/step - loss: 0.0489 - auc_6: 0.9818 - val_loss: 0.0488 - val_auc_6: 0.9799
# Epoch 3/5
# 2244/2244 [==============================] - 487s 217ms/step - loss: 0.0443 - auc_6: 0.9854 - val_loss: 0.0478 - val_auc_6: 0.9820
# Epoch 4/5
# 2244/2244 [==============================] - 489s 218ms/step - loss: 0.0410 - auc_6: 0.9879 - val_loss: 0.0472 - val_auc_6: 0.9799
# Epoch 5/5
# 2244/2244 [==============================] - 486s 216ms/step - loss: 0.0383 - auc_6: 0.9896 - val_loss: 0.0473 - val_auc_6: 0.9807
# Epoch 5: early stopping
# 63/63 [==============================] - 56s 879ms/step
#
# The mean column-wise ROC AUC score for LSTM with GloVe 6B 300D is 0.97743
#
#
#
# ============ GloVe 6B 300D - bidirectional LSTM ============
#
# Epoch 1/5
# 2244/2244 [==============================] - 1565s 696ms/step - loss: 0.0617 - auc_7: 0.9690 - val_loss: 0.0503 - val_auc_7: 0.9814
# Epoch 2/5
# 2244/2244 [==============================] - 1564s 697ms/step - loss: 0.0471 - auc_7: 0.9827 - val_loss: 0.0478 - val_auc_7: 0.9807
# Epoch 3/5
# 2244/2244 [==============================] - 1566s 698ms/step - loss: 0.0426 - auc_7: 0.9863 - val_loss: 0.0470 - val_auc_7: 0.9799
# Epoch 4/5
# 2244/2244 [==============================] - 1561s 695ms/step - loss: 0.0392 - auc_7: 0.9888 - val_loss: 0.0464 - val_auc_7: 0.9797
# Epoch 5/5
# 2244/2244 [==============================] - 1564s 697ms/step - loss: 0.0363 - auc_7: 0.9908 - val_loss: 0.0486 - val_auc_7: 0.9763
# Epoch 5: early stopping
# 63/63 [==============================] - 114s 2s/step
#
# The mean column-wise ROC AUC score for bidirectional LSTM with GloVe 6B 300D is 0.97825
